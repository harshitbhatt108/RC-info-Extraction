# %%
#Installing Pytesseract
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in e:\anaconda\envs\tensorflow\lib\site-packages (0.3.4)
# Requirement already satisfied: Pillow in e:\anaconda\envs\tensorflow\lib\site-packages (from pytesseract) (7.1.2)

# %%
#Installing tesseract
# !pip install tesseract
# Out:
# Requirement already satisfied: tesseract in e:\anaconda\envs\tensorflow\lib\site-packages (0.1.3)

# %%
#Installing pandas
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in e:\anaconda\envs\tensorflow\lib\site-packages (1.0.3)
# Requirement already satisfied: pytz>=2017.2 in e:\anaconda\envs\tensorflow\lib\site-packages (from pandas) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in e:\anaconda\envs\tensorflow\lib\site-packages (from pandas) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in e:\anaconda\envs\tensorflow\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in e:\anaconda\envs\tensorflow\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)

# %%
#Importing Essential Libraries
import pytesseract
import pandas as pd
from PIL import Image,ImageEnhance
import os

#assigning the directory link of Tesseract.exe
pytesseract.pytesseract.tesseract_cmd=r"Tesseract-OCR\tesseract.exe"

# %%
#Creating a list to store the images from RC folder
Rc_list=os.listdir('RC')
for i in range(len(Rc_list)):
    print(i,Rc_list[i])
# Out:
# 0 txt_mudit_b11_11597.jpg
# 1 txt_mudit_b11_11599.jpg
# 2 txt_mudit_b11_12.jpg
# 3 txt_mudit_b11_1328.jpg
# 4 txt_mudit_b11_1330.jpg
# 5 txt_mudit_b11_1332.jpg
# 6 txt_mudit_b11_1334.jpg
# 7 txt_mudit_b11_1337.jpg
# 8 txt_mudit_b11_1339.jpg
# 9 txt_mudit_b11_1343.jpg
# 10 txt_mudit_b11_1347.jpg
# 11 txt_mudit_b11_1354.jpg
# 12 txt_mudit_b11_1355.jpg
# 13 txt_mudit_b11_1361.jpg
# 14 txt_mudit_b11_1362.jpg
# 15 txt_mudit_b11_1363.jpg
# 16 txt_mudit_b11_1364.jpg
# 17 txt_mudit_b11_1365.jpg
# 18 txt_mudit_b11_1369.jpg
# 19 txt_mudit_b11_1524.jpg
# 20 txt_mudit_b11_1529.jpg
# 21 txt_mudit_b11_1534.jpg
# 22 txt_mudit_b11_1535.jpg
# 23 txt_mudit_b11_1536.jpg
# 24 txt_mudit_b11_1539.jpg
# 25 txt_mudit_b11_439.jpg
# 26 txt_mudit_b11_480.jpg
# 27 txt_mudit_b11_746.jpg
# 28 txt_mudit_b11_961.jpg
# 29 txt_mudit_b8_1_513.jpg
# 30 txt_mudit_b8_1_545.jpg
# 31 txt_mudit_b8_1_546.jpg
# 32 txt_mudit_b8_1_554.jpg
# 33 txt_mudit_b8_1_555.jpg
# 34 txt_mudit_b8_1_571.jpg
# 35 txt_mudit_b8_1_573.jpg
# 36 txt_mudit_b8_1_574.jpg
# 37 txt_mudit_b8_1_740.jpg
# 38 txt_mudit_b8_1_741.jpg
# 39 txt_mudit_b8_1_742.jpg
# 40 txt_mudit_b8_1_806.jpg
# 41 txt_mudit_b8_1_807.jpg
# 42 txt_mudit_b8_1_808.jpg
# 43 txt_mudit_b8_1_854.jpg
# 44 txt_mudit_b8_1_855.jpg
# 45 txt_mudit_b8_2_213.jpg

# %%
data=[]
j=0
for pictures in Rc_list:
    
     # 'RC/'+pictures is the directory of test images. 
    # Pictures are taken one at a time
    img=Image.open('RC\\'+pictures)                              
    
    # ImageEnhance helps the images to be processed in a better way.
    
    #Enhancing Brightnesss
    enhanced_img=ImageEnhance.Brightness(img)                         
    img=enhanced_img.enhance(1.2)
    
    #Enhancing Color
    enhanced_img=ImageEnhance.Color(img)
    img=enhanced_img.enhance(0.0)
    
    #Converting Image to string
    text=pytesseract.image_to_string(img)
    
    # spliting the text according the spaces
    new_str=text.split()                                   
    
    #initializing a list which holds the required 6 values needed from a image
    info_list=[None]*6                                            
    data.append(info_list)
    two=0
    for i in range(len(new_str)-6):
        
     #Exctracting the "License plate number or Regn number"  
        if new_str[i]=='REGN':
            if len(new_str[i+4])<9:
                    a=new_str[i+4]+new_str[i+5]
                    data[j][0]=a
            else:
                data[j][0]=new_str[i+4]
        else:
            if new_str[i]=='REGN.':
                if len(new_str[i+3])<9:
                    a=new_str[i+3]+new_str[i+4]
                    data[j][0]=a
                else:
                    data[j][0]=new_str[i+3]
        if new_str[i]=="Registration":
            if new_str[i+1]=="No.":
                if len(new_str[i+2])<9:
                    a=new_str[i+2]+new_str[i+3]
                    data[j][0]=a
                else:
                    data[j][0]=new_str[i+2]
                
        if 'HR' in new_str[i]:
            data[j][0]==new_str[i]
        
            
    # Extracting the "VIN number or Chassis number (Typically 17 digit long)"   
        if new_str[i]=='CH.' or new_str[i]=='CH' :    
            data[j][1]=new_str[i+3]
            
        if new_str[i]=="Chassis" or new_str[i]=="Chasis":
            if new_str[i+1]=="No.":
                data[j][1]=new_str[i+2]
        
        
    #Extracting the "Name"  
        if new_str[i]=='NAME' or new_str[i]=='Name' or new_str[i]=='name':
            if '_' or '-' in new_str[i+1]:
                if new_str[i+2]==':' or new_str[i+1]==':.':
                    if new_str[i+3]=='MR' or new_str[i+3]=='mr' or new_str[i+3]=='Mr' or new_str[i+3]=='MR.' or new_str[i+3]=='mr.' or new_str[i+3]=='Mr.':
                        name=new_str[i+4]
                    else:
                        name=new_str[i+3]
                else:
                    if new_str[i+2]=='MR' or new_str[i+2]=='mr' or new_str[i+2]=='Mr' or new_str[i+2]=='MR.' or new_str[i+2]=='mr.' or new_str[i+2]=='Mr.':
                        name=new_str[i+3]
                    else:
                        name=new_str[i+2]
                    
            elif new_str[i+1]==':' or new_str[i+1]==':.':
                    if new_str[i+2]=='MR' or new_str[i+2]=='mr' or new_str[i+2]=='Mr' or new_str[i+2]=='MR.' or new_str[i+2]=='mr.' or new_str[i+2]=='Mr.':
                        name=new_str[i+3]
                    else:
                        name=new_str[i+2]
            elif new_str[i+1]=='MR' or new_str[i+1]=='mr' or new_str[i+1]=='Mr' or new_str[i+1]=='MR.' or new_str[i+1]=='mr.' or new_str[i+1]=='Mr.' :
                name=new_str[i+2]
            
            elif new_str[i-1]=="Owner's":
                name=new_str[i+1]
            elif "&" in new_str[i+1]:
                name=new_str[i+4] #i+4
            else:
                name=new_str[i+1]
            if two==0:
                data[j][2]=name
                two=1
                
                
    #Extracting the "Engine number" 
        if new_str[i]=='ENO':
            if new_str[i+1]=='-' or new_str[i+1]=='_':
                data[j][3]=new_str[i+3]
            else:
                if new_str[i+2][-1]=='-':
                    a=str(new_str[i+2])+str(new_str[i+3])
                    data[j][3]=a
                else:
                    data[j][3]=new_str[i+2]
        if new_str[i]=="Engine":
            if len(new_str[i+2])<11:
                a=new_str[i+2]+new_str[i+3]
                data[j][3]=a
            else:
                data[j][3]=new_str[i+2]
                


    # Extracting the "Registration date" 
        if new_str[i]=="REG." or new_str[i]=="REGN":
            if "DT" in new_str[i+1]:
                if new_str[i+2]==":":
                    reg_date=new_str[i+3]
                else:
                    reg_date=new_str[i+2]
                length=len(reg_date)
                reg_date=reg_date[:length-8]+" / "+reg_date[length-7:length-5]+" / "+reg_date[length-4:]        
            
                data[j][4]=reg_date
        
        
        
    #Extracting the "Mfg. date" 
        if new_str[i]=="Year":
            if new_str[i+1]=="of":
                if "Manu" in new_str[i+2]:
                    manufacture_date=new_str[i+3]
            length=len(manufacture_date)
            manufacture_date=manufacture_date[:length-5]+" / "+manufacture_date[length-4:]
            data[j][5]=manufacture_date
            
        if new_str[i]=="Yr":
            if new_str[i+1]=="of":
                manufacture_date=new_str[i+2]
            length=len(manufacture_date)
            manufacture_date=manufacture_date[:length-5]+" / "+manufacture_date[length-4:]
            data[j][5]=manufacture_date
        
        
        
        if new_str[i]=="Month":
            if new_str[i+3]=="of":
                if new_str[i+4]=="Mfg." or new_str[i+4]=="Mfg" or new_str[i+4]=="Mig." or new_str[i+4]=="Mig":
                    manufacture_date=new_str[i+5]
            length=len(manufacture_date)
            manufacture_date=manufacture_date[:length-5]+"/"+manufacture_date[length-4:]
            data[j][5]=manufacture_date   
        
        if "MFG" in new_str[i]:
            if new_str[i+1]==":":
                manufacture_date=new_str[i+2]
            elif "DT" in new_str[i+1]:
                if new_str[i+2]==":":
                    manufacture_date=new_str[i+3]
                else:
                    manufacture_date=new_str[i+2]
            else:
                manufacture_date=new_str[i+1]
            length=len(manufacture_date)
            manufacture_date=manufacture_date[:length-5]+"/"+manufacture_date[length-4:]
            data[j][5]=manufacture_date
        
        
    j+=1

# %%
#Creating a Dataframe for the data extracted
df=pd.DataFrame(data)
df.columns=["Regn number","Chassis number","Name","Engine number","Registration date","Mfg. date"]
df
# Out:
#      Regn number       Chassis number      Name       Engine number  \
# 0           None                 None      None                None
# 1     DL9CAC6215                 None     smsim                None
# 2   DL2CAT9109""    Masetoetsooztesss    cELERI             rserose
# 3      HROGP5988    MASEYD81500765439     SINGH                None
# 4       HROS8814                 None       «-~                None
# 5      HRASD0002    MASFJEB1$00404062      NATH       D13A22350Fue!
# 6     HROGAH1768    MASELMG1800384208    HARISH        K14BN7124809
# 7           None                 None     KUMAR                None
# 8     HROGAER2A3    MA3EJKD1$00683213     VINAY        K12MM1830003
# 9     HROGAK2102     MAFHEB1S00B§2684  JITENDER         D13A2099227
# 10    DL2CAUTII7                 None      None                None
# 11    DL2CAS1294               COLOUR      ANIK        K12MN1262597
# 12    DL3CBU4111               COLOUR   SAURABH         DisA1e33010
# 13    DL13CA8614    MA3FHEB1S00593004    RAKESH        D13A-2307188
# 14    DL9CAC1454    MASEADE1500237206   KUMUDHA                None
# 15           NO:                    ©    SACHIN                   :
# 16           NO:    MM3FMEB1So09s1308    Kapoor                   :
# 17    DL8CAH3172    MASETDE1S00159552   CHANDRA                None
# 18     DLSCJ7852    MASFJEB1S00828720    MEGHNA         DisAz3e8220
# 19     DL5CJ5387                 None     NacAR                None
# 20     DL8CU7889   MA3EUA6G1SO0170565     MAMTA        FBDN49598005
# 21     DLeCN3195    MASEWDE1SO0637165      None        K10BN4590508
# 22     DLSCJ4987                 None   MANJULA        K10BN7228183
# 23     DL8CP6677                  ENO      None                None
# 24          None                 None      None                None
# 25          None                MAGE!     MANOJ                None
# 26         EcmJ"                 None      None                None
# 27          None                 None      None                None
# 28     DLSCJ6088    MASFHEB1S00520199   RAJNISH         D13A2235055
# 29    DL2CAMO993    MALBBS1BLAM217697     KAMAL       G4LAAM4SSO$SS
# 30          None       MA3EED81800628      None        F10DN4452456
# 31          None                 None   Vehicle                None
# 32    HR10_p_o84                    -   Address      -_G4EBIM246677
# 33          None                 None    MOTORS                None
# 34    DL3CAX6515      GO7146KRZWO0622     VIKAS    475IDTH4KRZPBSMQ
# 35    DL3CAX6515      6O7146KRZWO0622     VIKAS  47SIDTH4KRZPB8AM!9
# 36   DL3CAX6G515     EO7T14EKRZNOOEZZ      None               CLASS
# 37    DL2CAF6866                 None      None                None
# 38    DL2CAF6866                   NO      swiD                None
# 39    DL3CAD3216                 None   MAHABIR                None
# 40          None                 None      None                None
# 41          None  MALCM41VROMO79263*L   Address        D4FA9US17848
# 42          None                 None    MOTORS                None
# 43          None                 None      None                None
# 44          None                 None      None                None
# 45          None                 None      None                None
#
#    Registration date      Mfg. date
# 0               None           None
# 1               None           None
# 2               None           None
# 3               None       9 / 2006
# 4               None     9 / / 2006
# 5               None       9 / 2013
# 6               None       4 / 2016
# 7               None       4 //2016
# 8               None       1 / 2016
# 9               None       9 / 2018
# 10              None           None
# 11              None           None
# 12     o / o8 / 2012            /CD
# 13    11 / 02 / 2014         0/2014
# 14     1 / 08 / 2011        08/2011
# 15    07 / 05 / 2016           None
# 16       / so / rors           None
# 17              None         1/2014
# 18    17 / 08 / 2014        04/2014
# 19              None           None
# 20    14 / 02 / 2013        12/2012
# 21     3 / 71 / 2013            /CD
# 22    12 / 04 / 2013        02/2013
# 23              None           None
# 24              None        02/2013
# 25              None            /CD
# 26              None           None
# 27              None           None
# 28      Ar /  / rete             /'
# 29     1 / 70 / 2010            /CD
# 30              None  23/0|/ / 008_
# 31              None           None
# 32              None            / _
# 33              None           None
# 34    24 / 04 / 2009        10/2008
# 35   241 / 4/ / 0098        40/2008
# 36              None         T/TAEL
# 37              None           None
# 38    03 / 04 / 2006           None
# 39              None            /CD
# 40              None           None
# 41              None   31/12 / 2009
# 42              None           None
# 43              None           None
# 44              None           None
# 45              None           None

# %%
#Converting the Dataframe to csv(excel) file
df.to_csv('RC_info.csv')

# %%
#Reading the Data from RC_info.csv
import csv

with open('RC_info.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(f'\t{row[0]} Regn number {row[1]} , Chasis Number {row[2]},Name {row[3]},Engine Number {row[4]},Reg. Date {row[5]}, Mfg. Date {row[6]}.')
            line_count += 1
    #Displaying the number of lines processed
    print(f'Processed {line_count} lines.')
# Out:
# Column names are , Regn number, Chassis number, Name, Engine number, Registration date, Mfg. date
# 	0 Regn number  , Chasis Number ,Name ,Engine Number ,Reg. Date , Mfg. Date .
# 	1 Regn number DL9CAC6215 , Chasis Number ,Name smsim,Engine Number ,Reg. Date , Mfg. Date .
# 	2 Regn number DL2CAT9109"" , Chasis Number Masetoetsooztesss,Name cELERI,Engine Number rserose,Reg. Date , Mfg. Date .
# 	3 Regn number HROGP5988 , Chasis Number MASEYD81500765439,Name SINGH,Engine Number ,Reg. Date , Mfg. Date 9 / 2006.
# 	4 Regn number HROS8814 , Chasis Number ,Name Â«-~,Engine Number ,Reg. Date , Mfg. Date 9 / / 2006.
# 	5 Regn number HRASD0002 , Chasis Number MASFJEB1$00404062,Name NATH,Engine Number D13A22350Fue!,Reg. Date , Mfg. Date 9 / 2013.
# 	6 Regn number HROGAH1768 , Chasis Number MASELMG1800384208,Name HARISH,Engine Number K14BN7124809,Reg. Date , Mfg. Date 4 / 2016.
# 	7 Regn number  , Chasis Number ,Name KUMAR,Engine Number ,Reg. Date , Mfg. Date 4 //2016.
# 	8 Regn number HROGAER2A3 , Chasis Number MA3EJKD1$00683213,Name VINAY,Engine Number K12MM1830003,Reg. Date , Mfg. Date 1 / 2016.
# 	9 Regn number HROGAK2102 , Chasis Number MAFHEB1S00BÂ§2684,Name JITENDER,Engine Number D13A2099227,Reg. Date , Mfg. Date 9 / 2018.
# 	10 Regn number DL2CAUTII7 , Chasis Number ,Name ,Engine Number ,Reg. Date , Mfg. Date .
# 	11 Regn number DL2CAS1294 , Chasis Number COLOUR,Name ANIK,Engine Number K12MN1262597,Reg. Date , Mfg. Date .
# 	12 Regn number DL3CBU4111 , Chasis Number COLOUR,Name SAURABH,Engine Number DisA1e33010,Reg. Date o / o8 / 2012, Mfg. Date /CD.
# 	13 Regn number DL13CA8614 , Chasis Number MA3FHEB1S00593004,Name RAKESH,Engine Number D13A-2307188,Reg. Date 11 / 02 / 2014, Mfg. Date 0/2014.
# 	14 Regn number DL9CAC1454 , Chasis Number MASEADE1500237206,Name KUMUDHA,Engine Number ,Reg. Date 1 / 08 / 2011, Mfg. Date 08/2011.
# 	15 Regn number NO: , Chasis Number Â©,Name SACHIN,Engine Number :,Reg. Date 07 / 05 / 2016, Mfg. Date .
# 	16 Regn number NO: , Chasis Number MM3FMEB1So09s1308,Name Kapoor,Engine Number :,Reg. Date  / so / rors, Mfg. Date .
# 	17 Regn number DL8CAH3172 , Chasis Number MASETDE1S00159552,Name CHANDRA,Engine Number ,Reg. Date , Mfg. Date 1/2014.
# 	18 Regn number DLSCJ7852 , Chasis Number MASFJEB1S00828720,Name MEGHNA,Engine Number DisAz3e8220,Reg. Date 17 / 08 / 2014, Mfg. Date 04/2014.
# 	19 Regn number DL5CJ5387 , Chasis Number ,Name NacAR,Engine Number ,Reg. Date , Mfg. Date .
# 	20 Regn number DL8CU7889 , Chasis Number MA3EUA6G1SO0170565,Name MAMTA,Engine Number FBDN49598005,Reg. Date 14 / 02 / 2013, Mfg. Date 12/2012.
# 	21 Regn number DLeCN3195 , Chasis Number MASEWDE1SO0637165,Name ,Engine Number K10BN4590508,Reg. Date 3 / 71 / 2013, Mfg. Date /CD.
# 	22 Regn number DLSCJ4987 , Chasis Number ,Name MANJULA,Engine Number K10BN7228183,Reg. Date 12 / 04 / 2013, Mfg. Date 02/2013.
# 	23 Regn number DL8CP6677 , Chasis Number ENO,Name ,Engine Number ,Reg. Date , Mfg. Date .
# 	24 Regn number  , Chasis Number ,Name ,Engine Number ,Reg. Date , Mfg. Date 02/2013.
# 	25 Regn number  , Chasis Number MAGE!,Name MANOJ,Engine Number ,Reg. Date , Mfg. Date /CD.
# 	26 Regn number EcmJ" , Chasis Number ,Name ,Engine Number ,Reg. Date , Mfg. Date .
# 	27 Regn number  , Chasis Number ,Name ,Engine Number ,Reg. Date , Mfg. Date .
# 	28 Regn number DLSCJ6088 , Chasis Number MASFHEB1S00520199,Name RAJNISH,Engine Number D13A2235055,Reg. Date Ar /  / rete, Mfg. Date /'.
# 	29 Regn number DL2CAMO993 , Chasis Number MALBBS1BLAM217697,Name KAMAL,Engine Number G4LAAM4SSO$SS,Reg. Date 1 / 70 / 2010, Mfg. Date /CD.
# 	30 Regn number  , Chasis Number MA3EED81800628,Name ,Engine Number F10DN4452456,Reg. Date , Mfg. Date 23/0|/ / 008_.
# 	31 Regn number  , Chasis Number ,Name Vehicle,Engine Number ,Reg. Date , Mfg. Date .
# 	32 Regn number HR10_p_o84 , Chasis Number -,Name Address,Engine Number -_G4EBIM246677,Reg. Date , Mfg. Date  / _.
# 	33 Regn number  , Chasis Number ,Name MOTORS,Engine Number ,Reg. Date , Mfg. Date .
# 	34 Regn number DL3CAX6515 , Chasis Number GO7146KRZWO0622,Name VIKAS,Engine Number 475IDTH4KRZPBSMQ,Reg. Date 24 / 04 / 2009, Mfg. Date 10/2008.
# 	35 Regn number DL3CAX6515 , Chasis Number 6O7146KRZWO0622,Name VIKAS,Engine Number 47SIDTH4KRZPB8AM!9,Reg. Date 241 / 4/ / 0098, Mfg. Date 40/2008.
# 	36 Regn number DL3CAX6G515 , Chasis Number EO7T14EKRZNOOEZZ,Name ,Engine Number CLASS,Reg. Date , Mfg. Date T/TAEL.
# 	37 Regn number DL2CAF6866 , Chasis Number ,Name ,Engine Number ,Reg. Date , Mfg. Date .
# 	38 Regn number DL2CAF6866 , Chasis Number NO,Name swiD,Engine Number ,Reg. Date 03 / 04 / 2006, Mfg. Date .
# 	39 Regn number DL3CAD3216 , Chasis Number ,Name MAHABIR,Engine Number ,Reg. Date , Mfg. Date /CD.
# 	40 Regn number  , Chasis Number ,Name ,Engine Number ,Reg. Date , Mfg. Date .
# 	41 Regn number  , Chasis Number MALCM41VROMO79263*L,Name Address,Engine Number D4FA9US17848,Reg. Date , Mfg. Date 31/12 / 2009.
# 	42 Regn number  , Chasis Number ,Name MOTORS,Engine Number ,Reg. Date , Mfg. Date .
# 	43 Regn number  , Chasis Number ,Name ,Engine Number ,Reg. Date , Mfg. Date .
# 	44 Regn number  , Chasis Number ,Name ,Engine Number ,Reg. Date , Mfg. Date .
# 	45 Regn number  , Chasis Number ,Name ,Engine Number ,Reg. Date , Mfg. Date .
# Processed 47 lines.
